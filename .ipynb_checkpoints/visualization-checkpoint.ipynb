# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import geopandas as gpd

# %%
sf_locations_df = pd.read_csv('sf_locations.csv')
sf_neighborhoods_df = gpd.read_file('sf_neighborhoods.geojson')
sf_waymo_estimates_df = pd.read_csv('sf_waymo_estimates.csv')

# %%
sf_waymo_estimates_df.head()
# Out:
#      request_timestamp                               pickup_name  \
# 0  2025-01-17 16:59:34                        Ingleside Sundiall
# 1  2025-01-17 16:59:48  United States Postal Service India Basin
# 2  2025-01-17 17:00:07                   Presidio Branch Library
# 3  2025-01-17 17:00:22                        Folsom St & 8th St
# 4  2025-01-17 17:00:40                    Fillmore St & Union St
#
#   pickup_neighborhood  pickup_latitude  pickup_longitude pickup_time  \
# 0  Ingleside Terraces        37.724732       -122.468768       17:07
# 1         India Basin        37.739925       -122.381042       17:09
# 2     Pacific Heights        37.788852       -122.444892       17:06
# 3     South of Market        37.775002       -122.410091       17:09
# 4        Union Street        37.797097       -122.435518       17:05
#
#   pickup_date  pickup_wait_time_mins                dropoff_name  \
# 0  01/17/2025                      8          UCSF Dental Center
# ...
